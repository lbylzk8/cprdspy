# %%
from spiral import *

# %%
logSpiral(6, 1, 1, 1.25)

# %%
calla(4,1,12,0,['b']*12)

# %%
from cprdspy.CPR_matplotlib import *
from spiral import *
import numpy as np
flowers_mpl(n=6,ratio=np.sqrt(1.3),N=18,M=6)
for i in range(18):
    logSpiral_out(6, 1, 1, 0.7,theta=3*np.pi/8+i*np.pi/9)
# calla_by_petal(6,0.5, 4, 0, ["b"] * 4)
