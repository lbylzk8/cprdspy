# %%
from fourier_flower import *

# %%
print("=" * 60)
print("Fourier Flower — 傅里叶花瓣/花朵生成模块")
print("=" * 60)
print()
print("三种坐标系：")
print("  1. 极坐标  — fourier_polar_petal()")
print("     r(θ) = Σ aₘ cos(m·n·θ/2)")
print()
print("  2. 直角坐标 — fourier_cartesian_petal()")
print("     x(t) = Σ aₘˣ cos(mt) + bₘˣ sin(mt)")
print("     y(t) = Σ aₘʸ cos(mt) + bₘʸ sin(mt)")
print()
print("  3. 复数坐标 — fourier_complex_petal()")
print("     z(t) = Σ cₖ e^{ikt}")
print()
print("  4. 复数整花 — fourier_complex_flower()")
print("     利用 n 重旋转对称性约束，单条公式生成整朵花")
print("     cₖ ≠ 0 仅当 k ≡ 1 (mod n)")
print()
print("本轮可视化：")
print("  - plot_epicycle_flower() — 静态本轮结构图")
print("  - animate_epicycle_flower() — 动画：本轮旋转画出花朵")
print()
print("运行 demo_all() 查看所有风格的综合演示。")
print("运行 demo_compare_coordinates() 查看同一形状的三种等价表示。")
print()
# 运行演示
try:
    print("正在运行演示...")
    demo_all()
    plt.show()
except Exception as e:
        print(f"演示运行失败（可能在无 GUI 环境中）: {e}")
        print("模块导入成功，函数可在 Jupyter/脚本中正常使用。")
# Out:
# ============================================================
# Fourier Flower — 傅里叶花瓣/花朵生成模块
# ============================================================
#
# 三种坐标系：
#   1. 极坐标  — fourier_polar_petal()
#      r(θ) = Σ aₘ cos(m·n·θ/2)
#
#   2. 直角坐标 — fourier_cartesian_petal()
#      x(t) = Σ aₘˣ cos(mt) + bₘˣ sin(mt)
#      y(t) = Σ aₘʸ cos(mt) + bₘʸ sin(mt)
#
#   3. 复数坐标 — fourier_complex_petal()
#      z(t) = Σ cₖ e^{ikt}
#
#   4. 复数整花 — fourier_complex_flower()
#      利用 n 重旋转对称性约束，单条公式生成整朵花
#      cₖ ≠ 0 仅当 k ≡ 1 (mod n)
#
# 本轮可视化：
#   - plot_epicycle_flower() — 静态本轮结构图
#   - animate_epicycle_flower() — 动画：本轮旋转画出花朵
#
# 运行 demo_all() 查看所有风格的综合演示。
# 运行 demo_compare_coordinates() 查看同一形状的三种等价表示。
#
# 正在运行演示...
# 演示运行失败（可能在无 GUI 环境中）: name 'plt' is not defined
# 模块导入成功，函数可在 Jupyter/脚本中正常使用。
