# %%
from dot import *

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 6))
plt.axis("equal")
draw_n_dots_array(12, 12, rotation=np.pi/36, color="b", size=100)

# %%
dots=n_dots(3, 1)+n_dots(5, 1)+n_dots(8, 1)
draw_dots(dots)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(6, 6))
plt.axis("equal")
plt.axis("off")
dots = n_dots(n=12, R=1, a=3, b=1, p=2, q=2, rotation=0, shape="s", center=(0, 0))
draw_dots(dots,size=10,color=["red", "blue", "green","yellow","orange","purple","pink","brown","black","cyan","magenta","lime"])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(6, 6))
plt.axis("equal")
plt.axis("off")
draw_n_dots_array(n=12, m=3, R=1, a=1, b=1, p=2, q=2, rotation=0, d_rotation=180/24, shape="circle", direction="both", center=(0, 0), color_by="index",cmap="plasma", size=100, alpha=1)

# %%
dots = n_dots_array(n=12, m=72, d_rotation=np.pi / 72, direction="in")
color = (
    [
        "red",
        "blue",
        "green",
        "yellow",
        "orange",
        "purple",
        "pink",
        "brown",
        "black",
        "cyan",
        "magenta",
        "lime",
    ]
    * 2
    * 3
    * 6
)
draw_dots(dots, size=10, color_by="index", cmap="rainbow", alpha=1)
