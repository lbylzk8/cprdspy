# %%
from cprdspy.CPR_matplotlib import *

# %%
flower_mpl(n=3,N=1)

# %%
flower_mpl(n=4, N=1)

# %%
flower_mpl(n=5, N=1)

# %%
flower_mpl(n=6, N=1)

# %%
flower_mpl(n=7, N=1)

# %%
flower_mpl(n=8, N=1)

# %%
flower_mpl(n=9, N=1)

# %%
flower_mpl(n=10, N=1)

# %%
flower_mpl(n=11, N=1)

# %%
flower_mpl(n=12, N=1)
