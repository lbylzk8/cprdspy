# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
import numpy as np

# %%
flowers_mpl(n=3, ratio=1.6, N=15)

# %%
flowers_mpl(n=4, ratio=1.24, N=18)

# %%
flowers_mpl(n=4, ratio=1.16, N=24)

# %%
flowers_mpl(n=4, ratio=1.1, N=36)

# %%
flowers_mpl(n=4, ratio=1.4, N=12)

# %%
flowers_mpl(n=4, ratio=1.3,N=15)

# %%
flowers_mpl(n=4, ratio=1.26, N=16)

# %%
flowers_mpl(n=4, ratio=1.24, N=17)

# %%
flowers_mpl(n=4, ratio=1.24, N=18)

# %%
flowers_mpl(n=5, ratio=1.38, N=10)

# %%
flowers_mpl(n=5, ratio=1.21, N=15)

# %%
flowers_mpl(n=5, ratio=1.15, N=20)

# %%
flowers_mpl(n=6, ratio=1.7, N=6)

# %%
flowers_mpl(n=6, ratio=1.42, N=8)

# %%
flowers_mpl(n=6, ratio=1.33, N=9)

# %%
flowers_mpl(n=6, ratio=1.3, N=10)

# %%
flowers_mpl(n=6, ratio=1.26, N=11)

# %%
flowers_mpl(n=6, ratio=1.23, N=12)

# %%
flowers_mpl(n=6, ratio=1.1, N=24)

# %%
flowers_mpl(n=6, ratio=1.06, N=36)

# %%
flowers_mpl(n=7, ratio=1.22, N=11)

# %%
flowers_mpl(n=7, ratio=1.2, N=12)

# %%
flowers_mpl(n=7, ratio=1.18, N=13)

# %%
flowers_mpl(n=8, N=36, ratio=1.3)
