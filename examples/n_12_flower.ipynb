# %%
from cprdspy.CPR_matplotlib import *

# %%
flower_mpl(n=3)

# %%
flower_mpl(n=4)

# %%
flower_mpl(n=5)

# %%
flower_mpl(n=6)

# %%
flower_mpl(n=7)

# %%
flower_mpl(n=8)

# %%
flower_mpl(n=9)

# %%
flower_mpl(n=10)

# %%
flower_mpl(n=11)

# %%
flower_mpl(n=12)
