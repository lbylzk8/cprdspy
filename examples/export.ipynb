# %%
from cprdspy.CPR_matplotlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(
    figsize=(8, 8),
    facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
flowers_mpl(color="#f0f")
plt.savefig(
    "./images/canva_flower_1.png",
    dpi=1200,
    bbox_inches="tight",
)

# %%
plt.figure(
    figsize=(8, 8),
    facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
flowers_mpl(n=6,ratio=np.sqrt(1.5),color="#f0f")
plt.savefig(
    "./images/canva_flower_2.png",
    dpi=1200,
    bbox_inches="tight",
)

# %%
plt.figure(
    figsize=(8, 8),
    facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
plt.savefig(
    "./images/canva.png",
    dpi=1200,
    bbox_inches="tight",
)

# %%
plt.figure(
    figsize=(8, 8),
    facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
flowers_mpl(n=11,N=12,ratio=1.12,M=4,color="#f00")
plt.savefig(
    "./images/canva_flower_3.png",
    dpi=1200,
    bbox_inches="tight",
)

# %%
plt.figure(
    figsize=(8, 8),
    facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
flowers_mpl(n=8,N=8,ratio=1.3)
plt.savefig(
    "./images/canva_flower_4.png",
    dpi=1200,
    bbox_inches="tight",
)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

fig, ax = plt.subplots(
    figsize=(3, 3),
    facecolor="#000",
    # dpi=72
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
flowers_mpl(M=1, linewidth=5)
fig.set_size_inches(2, 2)
plt.savefig(
    "./images/flowers.svg",
    # dpi=256,
    bbox_inches="tight",
    pad_inches=0,
    transparent=True,
)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# 1. 创建正方形画布
fig, ax = plt.subplots(figsize=(6, 6))  # 直接用 figsize，不要用 set_size_inches
ax.set_aspect("equal")
ax.axis("off")

# 2. 绘图 - 确保 flowers_mpl 使用的是 currentColor
flowers_mpl(M=3, linewidth=2)  # 添加 color 参数

# 3. 保存
plt.savefig(
    "./images/icon.jpg",
    dpi=72,
    bbox_inches="tight",
    pad_inches=0,
    # transparent=True,
)

# %%
from PIL import Image

# 打开图片
img = Image.open("./images/icon.jpg")
# 调整尺寸
new_img = img.resize((128, 128))
# 保存图片
new_img.save("./images/icon128.jpg")

# %%
from cprdspy.CPR_matplotlib.Flowers.flower import *
import matplotlib.pyplot as plt
import numpy as np
plt.figure(
    figsize=(8, 8),
    # facecolor="#0f0",
)
ax = plt.gca()
ax.set_aspect("equal")
ax.axis("off")
colors=["#f00","#00f","#0f0"]*4
for i in range(9):
    flower_petal(n=6,rotation=i * 40+50, color=colors[i])
    flower_petal(R=1.35,r=1.35,n=6,rotation=i * 40+ 20+50, color=colors[i])
    flower_petal(R=1.35*1.35,r=1.35*1.35,n=6,rotation=(i+1) * 40+50, color=colors[i])
    # flower_petal(R=1.35*1.35*1.35,r=1.35*1.35*1.35,n=6,rotation=(i+1) * 40+20, color=colors[i])
    # flower_petal(R=1.35**4,r=1.35**4,n=6,rotation=(i+2) * 40, color=colors[i])
    # flower_petal(R=1.35**5,r=1.35**5,n=6,rotation=(i+2) * 40+20, color=colors[i])
plt.savefig(
    "./images/ternary.jpg",
    dpi=720,
    bbox_inches="tight",
    pad_inches=0,
    transparent=True,
)
