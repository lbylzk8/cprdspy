# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
import numpy as np

# %%
flowers_mpl(n=3,ratio=1.8,N=13)

# %%
flowers_mpl(n=4, ratio=1.39, N=13)

# %%
flowers_mpl(n=5, ratio=1.27, N=13)

# %%
flowers_mpl(n=6, ratio=1.2, N=13)

# %%
flowers_mpl(n=7, ratio=1.17, N=13)

# %%
flowers_mpl(n=8, ratio=1.16, N=13)

# %%
flowers_mpl(n=9, ratio=1.14, N=13)

# %%
flowers_mpl(n=10, ratio=1.12, N=13)

# %%
flowers_mpl(n=11, ratio=1.11, N=13)

# %%
flowers_mpl(n=12, ratio=1.1, N=13)

# %%
flowers_mpl(n=13, ratio=1.1, N=13)

# %%
flowers_mpl(n=14, ratio=1.1, N=13)

# %%
flowers_mpl(n=15, ratio=1.1, N=13)

# %%
flowers_mpl(n=16, ratio=1.09, N=13)

# %%
flowers_mpl(n=17, ratio=1.08, N=13)

# %%
flowers_mpl(n=18, ratio=1.07, N=13)
