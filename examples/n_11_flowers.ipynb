# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
import numpy as np

# %%
flowers_mpl(n=3, ratio=2.1, N=11)

# %%
flowers_mpl(n=4, ratio=1.5, N=11)

# %%
flowers_mpl(n=5, ratio=1.32, N=11)

# %%
flowers_mpl(n=6, ratio=1.26, N=11)

# %%
flowers_mpl(n=7, ratio=1.21, N=11)

# %%
flowers_mpl(n=8, ratio=1.19, N=11)

# %%
flowers_mpl(n=9, ratio=1.16, N=11)

# %%
flowers_mpl(n=10, ratio=1.15, N=11)

# %%
flowers_mpl(n=11, ratio=1.14, N=11)

# %%
flowers_mpl(n=12, ratio=1.13, N=11)

# %%
flowers_mpl(n=13, ratio=1.12, N=11)

# %%
flowers_mpl(n=14, ratio=1.11, N=11)

# %%
flowers_mpl(n=15, ratio=1.11, N=11)

# %%
flowers_mpl(n=16, ratio=1.1, N=11)

# %%
flowers_mpl(n=17, ratio=1.1, N=11)

# %%
flowers_mpl(n=18, ratio=1.1, N=11)
