# %%
from cprdspy.CPR_matplotlib.Arcs.arc import *
from cprdspy.CPR_matplotlib.Flowers.flower import *

# %%
arc()

# %%
oval_petal()

# %%
oval_petal(rotation=45,rot_by_center=False)

# %%
from cprdspy.CPR_matplotlib import *
oval_petal_mpl()

# %%
from cprdspy.CPR_matplotlib import *
# oval_petal_flower_mpl(1,2,0.5)
# oval_petal_flower_a_mpl(1,2,0.5)
# oval_petal_flower_a_mpl(12,8,3)
oval_flower_a_mpl(12,8,3,24,0,"#f88",1,(0,0),10000)
oval_flower_a_mpl(12,8,3,24,0,"#0f0",1,(0,0),2)
oval_flower_a_mpl(12,8,3,24,0,"#00f",0.5,(0,0),5)

# %%
from cprdspy.CPR_matplotlib import *
import numpy as np
flowers_mpl(1,1,8,np.sqrt(1.36),5,12)

# %%
from cprdspy.CPR_matplotlib import *
flowers_mpl(1,1,4)
flowers_mpl(1,1,4,points=4)
flowers_mpl(1,1,4,points=2)

# %%
from cprdspy.CPR_matplotlib import *
flowers_mpl(color="#0ff",M=6)

# %%
from cprdspy.CPR_matplotlib import *
flowers_mpl(n=5,ratio=1.3,color="#0ff")

# %%
from cprdspy.CPR_matplotlib import *
import numpy as np

# %%
flowers_mpl(n=6,ratio=np.sqrt(1.5),M=6,color="#0ff")

# %%
flowers_mpl(n=8,ratio=1.18,M=6,color="#0ff")

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
# plt.figure(figsize=(12, 12))
flowers_mpl(n=11,ratio=1.12,M=6,color="#0ff")
plt.axis("off")
# plt.savefig(
#     "./images/flowers_11_1.12_12_6.png", dpi=300, bbox_inches="tight", pad_inches=0
# )
# Out:
# (np.float64(-3.593340489327975),
#  np.float64(3.593340489327975),
#  np.float64(-3.593340489327975),
#  np.float64(3.593340489327975))

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(ratio=1.2, n=11, N=11,M=5,color="#0ff")
plt.savefig("./images/flowers_11_1.2_11_5.png", dpi=300, bbox_inches='tight', pad_inches=0)

# %%
plt.savefig("./images/flowers_11_1.2_11_5.png", dpi=300)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(n=10, ratio=1.13,M=8)
# plt.savefig(
    # "./images/flowers_10_1.13_12_8.png", dpi=600, bbox_inches="tight", pad_inches=0
# )

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(n=4, ratio=1.1, N=36,M=3)
# plt.savefig(
    # "./images/flowers_4_1.1_36_3.png", dpi=600, bbox_inches="tight", pad_inches=0
# )

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(n=5, ratio=1.15, N=20, M=5)
# plt.savefig(
#     "./images/flowers_5_1.15_20_5.png", dpi=600, bbox_inches="tight", pad_inches=0
# )

# %%
from cprdspy.CPR_matplotlib import *
# import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
# plt.axis("off")
flowers_mpl(ratio=1.2, n=8, N=12, M=7,color="#00f")

# %%
# 画板大小
import matplotlib.pyplot as plt
# plt.figure(figsize=(12,12))
plt.axis('off')
flowers_mpl(color="#f88",M=7)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(color="#f88",M=7,n=18,N=10,ratio=1.12)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(color="#0ff", M=11, n=9, N=12, ratio=1.15)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(color="#0ff", M=7, n=9, N=13, ratio=1.13)

# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
plt.axis("off")
flowers_mpl(color="#0ff", M=9, n=16, N=16, ratio=1.06)
# plt.savefig(
#     "./images/flowers_16_1.06_16_9.png", dpi=900, bbox_inches="tight", pad_inches=0
# )
