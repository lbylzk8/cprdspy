# %%
from cprdspy.CPR_matplotlib import *
import matplotlib.pyplot as plt
import numpy as np

# %%
flowers_mpl(n=4, ratio=1.1, N=12)

# %%
flowers_mpl(n=4, ratio=1.2, N=12)

# %%
flowers_mpl(n=4, ratio=1.3, N=12)

# %%
flowers_mpl(n=4, N=12)

# %%
flowers_mpl(n=4, ratio=1.5, N=12)

# %%
flowers_mpl(n=4, ratio=1.6, N=12)

# %%
flowers_mpl(n=4, ratio=1.7, N=12)

# %%
flowers_mpl(n=4, ratio=1.8, N=12)

# %%
flowers_mpl(n=4, ratio=1.9, N=12)

# %%
flowers_mpl(n=4, ratio=2, N=12)

# %%
flowers_mpl(n=4, ratio=2.1, N=12)

# %%
flowers_mpl(n=4, ratio=2.2, N=12)

# %%
flowers_mpl(n=4, ratio=2.3, N=12)

# %%
flowers_mpl(n=4, ratio=2.4, N=12)
