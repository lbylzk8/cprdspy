# %%
from cprdspy.CPR_matplotlib import *

# %%
flowers_mpl(n=3,ratio=3.3,N=8)

# %%
flowers_mpl(n=4, ratio=1.86, N=8)

# %%
flowers_mpl(n=5, ratio=1.55, N=8)

# %%
flowers_mpl(n=6, ratio=1.42, N=8)

# %%
flowers_mpl(n=7, ratio=1.35, N=8)

# %%
flowers_mpl(n=8, ratio=1.3, N=8)

# %%
flowers_mpl(n=9, ratio=1.28, N=8)

# %%
flowers_mpl(n=10, ratio=1.25, N=8)

# %%
flowers_mpl(n=11, ratio=1.23, N=8)

# %%
flowers_mpl(n=12, ratio=1.21, N=8)
